# %%
import pyrsimg
import matplotlib.pyplot as plt

# %%
path_img = '/Users/luo/Downloads/img/l9_scene_15.tif'
path_gpkg = '/Users/luo/Downloads/truth/l9_scene_15.gpkg'
path_mask = '/Users/luo/Downloads/l9_scene_15_mask.tif'
path_vec = '/Users/luo/Downloads/l9_scene_15_vector.gpkg'

# %%
mask = pyrsimg.raster_vec.vec2mask(path_vec=path_gpkg,path_raster=path_img, path_save=path_mask)

# %%
pyrsimg.raster_vec.raster2vec(path_raster=path_mask, 
                              path_save=path_vec, dn_values=[1])
# Out:
# 0
# 98

# %%
plt.imshow(mask, cmap='gray')
